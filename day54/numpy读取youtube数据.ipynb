# %%
import numpy as np
import matplotlib.pyplot as plt
us_file_path = "./youtube_video_data/US_video_data_numbers.csv"
uk_file_path = "./youtube_video_data/GB_video_data_numbers.csv"
# delimiter是分隔符，一般是unpack为false，一列为一个特征
t1 = np.loadtxt(us_file_path,delimiter=",",dtype="int",unpack=True)
t2 = np.loadtxt(us_file_path,delimiter=",",dtype="int")

print(t1)
print("*"*100)
print(t2)
print("*"*100)
# Out:
# [[4394029 7860119 5845909 ...  142463 2162240  515000]
#  [ 320053  185853  576597 ...    4231   41032   34727]
#  [   5931   26679   39774 ...     148    1384     195]
#  [  46245       0  170708 ...     279    4737    4722]]
# ****************************************************************************************************
# [[4394029  320053    5931   46245]
#  [7860119  185853   26679       0]
#  [5845909  576597   39774  170708]
#  ...
#  [ 142463    4231     148     279]
#  [2162240   41032    1384    4737]
#  [ 515000   34727     195    4722]]
# ****************************************************************************************************

# %%
t_us=t2
# 取评论的数据
t_us_comments = t_us[:,-1]
print(t_us.shape)
print(t_us_comments.shape)
# Out:
# (1688, 4)
# (1688,)

# %%
t_us_comments=t_us_comments[t_us_comments<=5000]
t_us_comments.shape
# Out:
# (1373,)

# %%
print(t_us_comments.max(),t_us_comments.min())
d=50
bin_nums = (t_us_comments.max()-t_us_comments.min())//d

# 绘图
plt.figure(figsize=(20,8),dpi=80)

plt.hist(t_us_comments,bin_nums)


plt.show()
# Out:
# 4995 0

# %%
import numpy as np
from matplotlib import pyplot as plt

us_file_path = "./youtube_video_data/US_video_data_numbers.csv"
uk_file_path = "./youtube_video_data/GB_video_data_numbers.csv"

# t1 = np.loadtxt(us_file_path,delimiter=",",dtype="int",unpack=True)
t_uk = np.loadtxt(uk_file_path,delimiter=",",dtype="int")

#选择喜欢数比50万小的数据
t_uk = t_uk[t_uk[:,1]<=500000]
print(t_uk)
t_uk_comment = t_uk[:,-1]
t_uk_like = t_uk[:,1]



plt.figure(figsize=(20,8),dpi=80)
plt.scatter(t_uk_like,t_uk_comment)

plt.show()
# Out:
# [[7426393   78240   13548     705]
#  [ 494203    2651    1309       0]
#  [ 142819   13119     151    1141]
#  ...
#  [ 109222    4840      35     212]
#  [ 626223   22962     532    1559]
#  [  99228    1699      23     135]]

# %%
#读取数据
us_file_path = "./youtube_video_data/USvideos1.csv"

#有字符串就读取不了，usecols读成功了以后选那几列
t_us = np.loadtxt(us_file_path,delimiter=",",usecols=(1,2),skiprows=1,encoding='utf8',dtype='int')
print(t_us.shape)
print(t_us)
t_us.dtype
# Out:
# (1688, 2)
# [[4394029  320053]
#  [7860119  185853]
#  [5845909  576597]
#  ...
#  [ 142463    4231]
#  [2162240   41032]
#  [ 515000   34727]]
# dtype('int64')
